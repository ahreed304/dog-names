# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

csv_path = "../resources/NYC_Dog_Licensing_Dataset.csv"
data = pd.read_csv(csv_path)
data
# Out:
#         RowNumber AnimalName AnimalGender  AnimalBirthMonth  \
# 0               1      PAIGE            F              2014
# 1               2       YOGI            M              2010
# 2               3        ALI            M              2014
# 3               4      QUEEN            F              2013
# 4               5       LOLA            F              2009
# ...           ...        ...          ...               ...
# 493067     147341    UNKNOWN            F              2020
# 493068     147342    UNKNOWN            F              2020
# 493069     147343    UNKNOWN            M              2020
# 493070     147344    UNKNOWN            M              2020
# 493071     147345    UNKNOWN            F              2020
#
#                                    BreedName  Borough  ZipCode  \
# 0       American Pit Bull Mix / Pit Bull Mix      NaN    10035
# 1                                      Boxer      NaN    10465
# ...

# %%
# Obtain a list of the columns in the dataset 
data.columns
# Out:
# Index(['RowNumber', 'AnimalName', 'AnimalGender', 'AnimalBirthMonth',
#        'BreedName', 'Borough', 'ZipCode', 'LicenseIssuedDate',
#        'LicenseExpiredDate', 'Extract Year', 'Unique Dog ID'],
#       dtype='object')

# %%
# Remove the columns that are not necessary 
data_subset = data[['RowNumber', 'AnimalName', 'AnimalGender', 'AnimalBirthMonth',
       'BreedName', 'ZipCode', 'LicenseIssuedDate',
       'LicenseExpiredDate']]
data_subset
# Out:
#         RowNumber AnimalName AnimalGender  AnimalBirthMonth  \
# 0               1      PAIGE            F              2014
# 1               2       YOGI            M              2010
# 2               3        ALI            M              2014
# 3               4      QUEEN            F              2013
# 4               5       LOLA            F              2009
# ...           ...        ...          ...               ...
# 493067     147341    UNKNOWN            F              2020
# 493068     147342    UNKNOWN            F              2020
# 493069     147343    UNKNOWN            M              2020
# 493070     147344    UNKNOWN            M              2020
# 493071     147345    UNKNOWN            F              2020
#
#                                    BreedName  ZipCode LicenseIssuedDate  \
# 0       American Pit Bull Mix / Pit Bull Mix    10035        09/12/2014
# 1                                      Boxer    10465        09/12/2014
# ...

# %%
# Rename the columns 
data_subset.columns = [
    "Row Number",
    "Dog Name", 
    "Gender",
    "Birth Year",
    "Breed",
    "Zip Code",
    "Issued Date",
    "Expired Date"]
data_subset
# Out:
#         Row Number Dog Name Gender  Birth Year  \
# 0                1    PAIGE      F        2014
# 1                2     YOGI      M        2010
# 2                3      ALI      M        2014
# 3                4    QUEEN      F        2013
# 4                5     LOLA      F        2009
# ...            ...      ...    ...         ...
# 493067      147341  UNKNOWN      F        2020
# 493068      147342  UNKNOWN      F        2020
# 493069      147343  UNKNOWN      M        2020
# 493070      147344  UNKNOWN      M        2020
# 493071      147345  UNKNOWN      F        2020
#
#                                        Breed  Zip Code Issued Date  \
# 0       American Pit Bull Mix / Pit Bull Mix     10035  09/12/2014
# 1                                      Boxer     10465  09/12/2014
# 2                                    Basenji     10013  09/12/2014
# 3                           Akita Crossbreed     10013  09/12/2014
# ...

# %%
# Check for any null values 
data_subset.isna().sum()
# Out:
# Row Number         0
# Dog Name        1062
# Gender            22
# Birth Year         0
# Breed              0
# Zip Code           0
# Issued Date        0
# Expired Date      65
# dtype: int64

# %%
# Check the null values in any column for example the dog name column 
data_subset[data_subset['Dog Name'].isna()]
# Out:
#         Row Number Dog Name Gender  Birth Year  \
# 1661          1662      NaN      M        2014
# 2095          2096      NaN      F        2014
# 2902          2903      NaN      M        2014
# 3258          3259      NaN      M        2014
# 3776          3777      NaN      F        2014
# ...            ...      ...    ...         ...
# 492335      146609      NaN      M        2020
# 492338      146612      NaN      F        2020
# 492341      146615      NaN      M        2020
# 492343      146617      NaN      M        2020
# 493008      147282      NaN      M        2020
#
#                                   Breed  Zip Code Issued Date Expired Date
# 1661                  Poodle, Miniature     10014  01/02/2015   01/02/2016
# 2095                          Chihuahua     11223  01/09/2015   01/09/2016
# 2902               Schnauzer, Miniature     10032  01/20/2015   01/20/2016
# 3258        Miniature American Shepherd     10016  01/25/2015   01/25/2016
# ...

# %%
# Generate descriptive statistics
data_subset.describe()
# Out:
#           Row Number     Birth Year       Zip Code
# count  493072.000000  493072.000000  493072.000000
# mean    62429.505699    2012.214176   10700.728405
# std     37038.123397      12.697143    1167.498005
# min         1.000000       1.000000       0.000000
# 25%     30817.750000    2009.000000   10031.000000
# 50%     61634.500000    2013.000000   10467.000000
# 75%     92451.250000    2016.000000   11228.000000
# max    147345.000000    2021.000000   99508.000000

# %%
# Get a feel for the type of information such as integers (int64) vs. strings(object)
data_subset.dtypes
# Out:
# Row Number       int64
# Dog Name        object
# Gender          object
# Birth Year       int64
# Breed           object
# Zip Code         int64
# Issued Date     object
# Expired Date    object
# dtype: object

# %%
# Retrieve all the values for Birth Year equal to or greater than 2014
data_subset[data_subset["Birth Year"]>=2014]
# Out:
#         Row Number Dog Name Gender  Birth Year  \
# 0                1    PAIGE      F        2014
# 2                3      ALI      M        2014
# 12              13     LUCY      F        2014
# 13              14    RICKY      M        2014
# 18              19    AVERY      F        2014
# ...            ...      ...    ...         ...
# 493067      147341  UNKNOWN      F        2020
# 493068      147342  UNKNOWN      F        2020
# 493069      147343  UNKNOWN      M        2020
# 493070      147344  UNKNOWN      M        2020
# 493071      147345  UNKNOWN      F        2020
#
#                                        Breed  Zip Code Issued Date  \
# 0       American Pit Bull Mix / Pit Bull Mix     10035  09/12/2014
# 2                                    Basenji     10013  09/12/2014
# 12           Dachshund Smooth Coat Miniature     11215  09/13/2014
# 13                       German Shepherd Dog     11220  09/13/2014
# ...

# %%
# Obtain the distribution of different names 
data_subset["Dog Name"].value_counts()
# Out:
# UNKNOWN              9344
# BELLA                5508
# NAME NOT PROVIDED    5054
# MAX                  4930
# CHARLIE              4021
#                      ...
# NEPOMNYASHCHAYA         1
# SYREE                   1
# WRENLY                  1
# SA-ING                  1
# BAEKTO                  1
# Name: Dog Name, Length: 26939, dtype: int64

# %%
# # string_value = "alphanumeric@123__"
# # s = ''.join(filter(str.isalnum, string_value))
# # print(s)

# # data_filtered = data_filtered[data['Dog Name'] != "NAME NOT PROVIDED"]

# # data_subset.isalnum()
# # data_subset


# # data_subset.str.isalpha()
# data_subset["Dog Name"] = data_subset["Dog Name"].str.replace(r'\W', "")
# print(data_subset)

# %%
# data.groupby(['AnimalBirthMonth'], as_index=False).count()

filtered_names = ["UNKOWN", "NAME NOT PROVIDED", "NO NAME", "NONE", ".", "-"]

data_filtered = data_subset[data_subset['Birth Year'] >= 2014]
data_filtered = data_filtered[data_subset['Dog Name'] != "UNKNOWN"]
data_filtered = data_filtered[data_subset['Dog Name'] != "NAME NOT PROVIDED"]
data_filtered = data_filtered[data_subset['Dog Name'] != "NO NAME"]
data_filtered = data_filtered[data_subset['Dog Name'] != "NAME"]
data_filtered = data_filtered[data_subset['Dog Name'] != "NONE"]
data_filtered = data_filtered[data_subset['Dog Name'] != "NaN"]
data_filtered = data_filtered[data_subset['Dog Name'] != "SA$$Y"]
data_filtered = data_filtered[data_subset['Dog Name'] != "$"]
data_filtered = data_filtered[data_subset['Dog Name'] != "."]
data_filtered = data_filtered[data_subset['Dog Name'] != "-"]
data_filtered = data_filtered[data_subset['Dog Name'] != "--"]
data_filtered = data_filtered[data_subset['Dog Name'] != "---"]
data_filtered = data_filtered[data_subset['Dog Name'] != "A"]
data_filtered = data_filtered[data_subset['Dog Name'] != "A."]
data_filtered = data_filtered[data_subset['Dog Name'] != "2"]
data_filtered = data_filtered[data_subset['Dog Name'] != "40804"]
data_filtered = data_filtered[data_subset['Dog Name'] != "90201"]
data_filtered = data_filtered[data_subset['Dog Name'] != "3010271"]
data_filtered = data_filtered[data_subset['Dog Name'] != "2003-08-13T00:00:00.000"]
data_filtered = data_filtered[data_subset['Dog Name'] != "2003-10-22T00:00:00.000"]
data_filtered = data_filtered[data_subset['Dog Name'] != "2005-08-19T00:00:00.000"]
data_filtered = data_filtered[data_subset['Dog Name'] != "2008-10-22T00:00:00.000"]
data_filtered = data_filtered[data_subset['Dog Name'] != "2004-10-22T00:00:00.000"]
data_filtered['temp'] = data_filtered['Zip Code'] + data_filtered['Birth Year']

data_filtered
# Out:
# /Users/emmadublin/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/emmadublin/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# /Users/emmadublin/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /Users/emmadublin/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# /Users/emmadublin/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.
# ...

# %%
# Obtain most common name in Dog Name column
data_filtered["Dog Name"].value_counts().idxmax()
# Out:
# 'BELLA'

# %%
# Obtain top 10 dog names in the filtered dataset
n = 10
data_filtered["Dog Name"].value_counts()[:n].index.tolist()
# Out:
# ['BELLA',
#  'LUNA',
#  'MAX',
#  'CHARLIE',
#  'COCO',
#  'LOLA',
#  'ROCKY',
#  'TEDDY',
#  'MILO',
#  'LUCY']

# %%
# Obtain all dog names in dataset 
pd.DataFrame(data_filtered["Dog Name"].value_counts())
# Out:
#            Dog Name
# BELLA          2333
# LUNA           2162
# MAX            1946
# CHARLIE        1795
# COCO           1420
# ...             ...
# RIGHI             1
# PISEK             1
# SURRENDER         1
# BISBEE            1
# BAEKTO            1
#
# [18494 rows x 1 columns]

# %%
data_filtered["Dog Name"][0].title()
# Out:
# 'Paige'

# %%
pd.DataFrame(data_filtered["Breed"].value_counts())
# Out:
#                                       Breed
# Yorkshire Terrier                     12685
# Shih Tzu                              10173
# Unknown                               10076
# American Pit Bull Mix / Pit Bull Mix   6920
# Labrador Retriever Crossbreed          6888
# ...                                     ...
# Mastiff, French (Dogue de Bordeaux)       1
# Karelian Bear Dog                         1
# Greek Shephard                            1
# Finnish Lapphund                          1
# Tornjak                                   1
#
# [325 rows x 1 columns]

# %%
pd.DataFrame(data_filtered["Birth Year"].value_counts())
# Out:
#       Birth Year
# 2016       43145
# 2015       42206
# 2014       38641
# 2017       34713
# 2018       23581
# 2019       18141
# 2020       10085
# 2021          25

# %%
data_filtered.groupby(['Gender'], as_index=False).count()
# Out:
#   Gender  Row Number  Dog Name  Birth Year   Breed  Zip Code  Issued Date  \
# 0      F       94124     93706       94124   94124     94124        94124
# 1      M      116413    115777      116413  116413    116413       116413
#
#    Expired Date    temp
# 0         94112   94124
# 1        116396  116413

# %%
# Generate a pie plot showing the distribution of female versus male dogs using Pandas

# Labels for the sections of our pie chart
labels = ["Female", "Male"]

# The values of each section of the pie chart
sizes = data_filtered.groupby(['Gender'], as_index=False).count()['Row Number']

# The colors of each section of the pie chart
colors = ["thistle", "cornflowerblue"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0)
plt.title("Distrubution of Female vs Male Dogs")

gender_pie = plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)

# %%
# data_subset = data_subset.drop(["Borough", "Extract Year", "Unique Dog ID"], axis=1)
# data_subset

# %%
#Removing duplicate dog licenses
data_filtered_1 = data_filtered[~(data_filtered.duplicated(['Zip Code', 'Birth Year', 'Dog Name']))]
data_filtered_1
# Out:
#         Row Number Dog Name Gender  Birth Year  \
# 0                1    PAIGE      F        2014
# 2                3      ALI      M        2014
# 12              13     LUCY      F        2014
# 13              14    RICKY      M        2014
# 18              19    AVERY      F        2014
# ...            ...      ...    ...         ...
# 493057      147331  SPELLER      F        2021
# 493059      147333     ADDY      F        2020
# 493060      147334     ELLA      F        2020
# 493061      147335   BAEKTO      M        2020
# 493062      147336    HAPPY      F        2016
#
#                                        Breed  Zip Code Issued Date  \
# 0       American Pit Bull Mix / Pit Bull Mix     10035  09/12/2014
# 2                                    Basenji     10013  09/12/2014
# 12           Dachshund Smooth Coat Miniature     11215  09/13/2014
# 13                       German Shepherd Dog     11220  09/13/2014
# ...

# %% [markdown]
# ## THE MOVIE DB API
# #### https://www.themoviedb.org/

# %%
#Dependencies for API
import requests
import json

import movie_api from api_key
# Out:
#   File "/var/folders/ns/k4l1jlxx3j36d90b23z0zjww0000gn/T/ipykernel_8414/1790788152.py", line 5
#     import movie_api from api_key
#                         ^
# SyntaxError: invalid syntax

# %%
#Set Equal to list of 'Release' column from Marvel dataset
marvel_movies = ['Avengers: Endgame', 'The Avengers','Thor']

# %%
movie_url = "https://api.themoviedb.org/3/search/movie?api_key="+movie_api

ids = []
titles = []
chars = []
char_count = []
for movie in marvel_movies:
    search = requests.get(movie_url + "&query="+movie).json()
    movie_id = search['results'][0]['id']
    
    cast_url = "https://api.themoviedb.org/3/movie/"+str(movie_id)+"/credits?api_key="+movie_api
    response = requests.get(cast_url).json()
    
    char_count.append(len(response['cast']))
        
    #Pulls character list for each movie and adds the movie id into the 'ids' list
    for i in range(0,(len(response['cast']))):
        chars.append(response['cast'][i]['character'])
        ids.append(movie_id)
        titles.append(movie)

# %%
#Creating DataFrame of all Marvel Characters in Each Marvel Movies
char_dict = {"Movie ID": ids, "Movie Title": titles,"Characters":chars}
full_char_list = pd.DataFrame(char_dict)
full_char_list

# %%
#List of Names To Check Against 
names = ['Thor','Tony','Wanda','Steve','Loki']

# %%
#Loops through list and appends name with _film to create a variable that has the list of Marvel moveies where that name appears
search_names = []
for name in names:
    locals()[name.lower()+"_films"] = []
    for i in range(0,len(full_char_list['Characters'])):
        if name.title() in (full_char_list['Characters'][i]):
            if full_char_list['Movie Title'][i] not in locals()[name.lower()+"_films"]:
                locals()[name.lower()+"_films"].append(full_char_list['Movie Title'][i])

print(thor_films)
print(wanda_films)
print(loki_films)
# Out:
#    Show ID               Characters
# 0    18721                 Narrator
# 1    18721  Dr. Donald Blake / Thor

# %%
#Find Character Names that match values in name list
search_names = []
name_count = []
for name in names:
    for i in range(0,len(show_cast_tbl['Characters'])):
        if name.title() in (show_cast_tbl['Characters'][i]):
            search_names.append("Match!")
            name_count.append(1)
        else:
            search_names.append("Not found!")
            name_count.append(0)

# %%
len(search_names)
# Out:
# 686

# %%
tbl_dict_2013 = {"Show ID": ids, "Characters":cast, "Dog Name?": search_names}
matches_2013 = pd.DataFrame(tbl_dict_2013)
matches_2013[matches_2013["Dog Name?"] == "Match!"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ns/k4l1jlxx3j36d90b23z0zjww0000gn/T/ipykernel_6980/2330932377.py in <module>
# ----> 1 tbl_dict_2013 = {"Show ID": ids, "Characters":cast, "Dog Name?": search_names}
#       2 matches_2013 = pd.DataFrame(tbl_dict_2013)
#       3 matches_2013[matches_2013["Dog Name?"] == "Match!"]
#
# NameError: name 'search_names' is not defined

# %%
movie_api = "775831db926527cf827f26799a2dd333"

#Set Equal to list of 'Release' column from Marvel dataset
marvel_movies = ['Avengers: Endgame', 'The Avengers','Thor']

movie_url = "https://api.themoviedb.org/3/search/movie?api_key="+movie_api

ids = []
titles = []
chars = []
char_count = []
for movie in marvel_movies:
    search = requests.get(movie_url + "&query="+movie).json()
    movie_id = search['results'][0]['id']
    
    cast_url = "https://api.themoviedb.org/3/movie/"+str(movie_id)+"/credits?api_key="+movie_api
    response = requests.get(cast_url).json()
    
    char_count.append(len(response['cast']))
        
    #Pulls character list for each movie and adds the movie id into the 'ids' list
    for i in range(0,(len(response['cast']))):
        chars.append(response['cast'][i]['character'])
        ids.append(movie_id)
        titles.append(movie)
          

char_dict = {"Movie ID": ids, "Movie Title": titles,"Characters":chars}
full_char_list = pd.DataFrame(char_dict)
full_char_list 

#Find Character Names that match values in name list
names = ['Thor','Tony','Wanda','Steve','Loki']

#Loops through list and appends name with _film to create a variable that has the list of Marvel moveies where that name appears
search_names = []
for name in names:
    locals()[name.lower()+"_films"] = []
    for i in range(0,len(full_char_list['Characters'])):
        if name.title() in (full_char_list['Characters'][i]):
            if full_char_list['Movie Title'][i] not in locals()[name.lower()+"_films"]:
                locals()[name.lower()+"_films"].append(full_char_list['Movie Title'][i])

print(thor_films)
print(wanda_films)
print(loki_films)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ns/k4l1jlxx3j36d90b23z0zjww0000gn/T/ipykernel_8414/4263427530.py in <module>
#      11 char_count = []
#      12 for movie in marvel_movies:
# ---> 13     search = requests.get(movie_url + "&query="+movie).json()
#      14     movie_id = search['results'][0]['id']
#      15
#
# NameError: name 'requests' is not defined

# %%
search_names
# Out:
# [0, 47, 56, 55, 127]

# %%
full_char_list['Movie Title'][search_names].unique().tolist()
# Out:
# ['Thor', 'Avengers: Age of Ultron', 'Iron Man']

# %%
rep['cast'][0]['character']
# Out:
# 'Thor Odinson'
