# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

csv_path = "../resources/NYC_Dog_Licensing_Dataset.csv"
data = pd.read_csv(csv_path)
data
# Out:
#         RowNumber AnimalName AnimalGender  AnimalBirthMonth  \
# 0               1      PAIGE            F              2014
# 1               2       YOGI            M              2010
# 2               3        ALI            M              2014
# 3               4      QUEEN            F              2013
# 4               5       LOLA            F              2009
# ...           ...        ...          ...               ...
# 493067     147341    UNKNOWN            F              2020
# 493068     147342    UNKNOWN            F              2020
# 493069     147343    UNKNOWN            M              2020
# 493070     147344    UNKNOWN            M              2020
# 493071     147345    UNKNOWN            F              2020
#
#                                    BreedName  Borough  ZipCode  \
# 0       American Pit Bull Mix / Pit Bull Mix      NaN    10035
# 1                                      Boxer      NaN    10465
# 2                                    Basenji      NaN    10013
# 3                           Akita Crossbreed      NaN    10013
# 4                                    Maltese      NaN    10028
# ...                                      ...      ...      ...
# 493067                     Poodle Crossbreed      NaN    10025
# 493068             Coonhound, Treeing Walker      NaN    11201
# 493069                             Dachshund      NaN    11206
# 493070                          Goldendoodle      NaN    10019
# 493071                            Pomeranian      NaN    11212
#
#        LicenseIssuedDate LicenseExpiredDate  Extract Year  Unique Dog ID
# 0             09/12/2014         09/12/2017        2016.0            NaN
# 1             09/12/2014         10/02/2017        2016.0            NaN
# 2             09/12/2014         09/12/2019        2016.0            NaN
# 3             09/12/2014         09/12/2017        2016.0            NaN
# 4             09/12/2014         10/09/2017        2016.0            NaN
# ...                  ...                ...           ...            ...
# 493067        03/17/2021         03/17/2022           NaN            NaN
# 493068        03/17/2021         03/17/2022           NaN            NaN
# 493069        03/17/2021         03/17/2022           NaN            NaN
# 493070        03/17/2021         03/17/2022           NaN            NaN
# 493071        03/17/2021         03/17/2022           NaN            NaN
#
# [493072 rows x 11 columns]

# %%
data.groupby(['AnimalGender'], as_index=False).count()
# Out:
#   AnimalGender  RowNumber  AnimalName  AnimalBirthMonth  BreedName  Borough  \
# 0            F     223772      223347            223772     223772        0
# 1            M     269278      268641            269278     269278        0
#
#    ZipCode  LicenseIssuedDate  LicenseExpiredDate  Extract Year  Unique Dog ID
# 0   223772             223772              223744        156548              0
# 1   269278             269278              269241        189161              0

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# Labels for the sections of our pie chart
labels = ["Female", "Male"]

# The values of each section of the pie chart
sizes = data.groupby(['AnimalGender'], as_index=False).count()['RowNumber']

# The colors of each section of the pie chart
colors = ["thistle", "cornflowerblue"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0)
plt.title("Distrubution of Female vs Male Dogs")

gender_pie = plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)

# %%
# data.groupby(['AnimalBirthMonth'], as_index=False).count()

filtered_names = ["UNKOWN", "NAME NOT PROVIDED"]

data_filtered = data[data['AnimalBirthMonth'] >= 2014]
data_filtered = data_filtered[data['AnimalName'] != "UNKNOWN"]
data_filtered = data_filtered[data['AnimalName'] != "NAME NOT PROVIDED"]
data_filtered['temp'] = data_filtered['ZipCode'] + data_filtered['AnimalBirthMonth']

data_filtered
# Out:
# /var/folders/5_/v3fy0_010mg6spkpddjy3qcrnbcdvr/T/ipykernel_8374/3544711620.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_filtered = data_filtered[data['AnimalName'] != "UNKNOWN"]
# /var/folders/5_/v3fy0_010mg6spkpddjy3qcrnbcdvr/T/ipykernel_8374/3544711620.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_filtered = data_filtered[data['AnimalName'] != "NAME NOT PROVIDED"]
#         RowNumber AnimalName AnimalGender  AnimalBirthMonth  \
# 0               1      PAIGE            F              2014
# 2               3        ALI            M              2014
# 12             13       LUCY            F              2014
# 13             14      RICKY            M              2014
# 18             19      AVERY            F              2014
# ...           ...        ...          ...               ...
# 493057     147331    SPELLER            F              2021
# 493059     147333       ADDY            F              2020
# 493060     147334       ELLA            F              2020
# 493061     147335     BAEKTO            M              2020
# 493062     147336      HAPPY            F              2016
#
#                                    BreedName  Borough  ZipCode  \
# 0       American Pit Bull Mix / Pit Bull Mix      NaN    10035
# 2                                    Basenji      NaN    10013
# 12           Dachshund Smooth Coat Miniature      NaN    11215
# 13                       German Shepherd Dog      NaN    11220
# 18        American Pit Bull Terrier/Pit Bull      NaN    10002
# ...                                      ...      ...      ...
# 493057                     Poodle Crossbreed      NaN    11203
# 493059                             Chihuahua      NaN    11693
# 493060                             Chihuahua      NaN    11693
# 493061                      Jindo Dog, Korea      NaN    11249
# 493062                  Old English Sheepdog      NaN    10024
#
#        LicenseIssuedDate LicenseExpiredDate  Extract Year  Unique Dog ID  \
# 0             09/12/2014         09/12/2017        2016.0            NaN
# 2             09/12/2014         09/12/2019        2016.0            NaN
# 12            09/13/2014         09/13/2019        2016.0            NaN
# 13            09/13/2014         09/13/2017        2016.0            NaN
# 18            09/13/2014         09/13/2019        2016.0            NaN
# ...                  ...                ...           ...            ...
# 493057        03/17/2021         03/17/2022           NaN            NaN
# 493059        03/17/2021         03/17/2022           NaN            NaN
# 493060        03/17/2021         03/17/2022           NaN            NaN
# 493061        03/17/2021         03/17/2022           NaN            NaN
# 493062        03/17/2021         03/17/2026           NaN            NaN
#
#          temp
# 0       12049
# 2       12027
# 12      13229
# 13      13234
# 18      12016
# ...       ...
# 493057  13224
# 493059  13713
# 493060  13713
# 493061  13269
# 493062  12040
#
# [213548 rows x 12 columns]

# %%
data_filtered = data_filtered[~(data_filtered.duplicated(['ZipCode', 'AnimalBirthMonth', 'AnimalName']))]
data_filtered
# Out:
#         RowNumber AnimalName AnimalGender  AnimalBirthMonth  \
# 0               1      PAIGE            F              2014
# 2               3        ALI            M              2014
# 12             13       LUCY            F              2014
# 13             14      RICKY            M              2014
# 18             19      AVERY            F              2014
# ...           ...        ...          ...               ...
# 493057     147331    SPELLER            F              2021
# 493059     147333       ADDY            F              2020
# 493060     147334       ELLA            F              2020
# 493061     147335     BAEKTO            M              2020
# 493062     147336      HAPPY            F              2016
#
#                                    BreedName  Borough  ZipCode  \
# 0       American Pit Bull Mix / Pit Bull Mix      NaN    10035
# 2                                    Basenji      NaN    10013
# 12           Dachshund Smooth Coat Miniature      NaN    11215
# 13                       German Shepherd Dog      NaN    11220
# 18        American Pit Bull Terrier/Pit Bull      NaN    10002
# ...                                      ...      ...      ...
# 493057                     Poodle Crossbreed      NaN    11203
# 493059                             Chihuahua      NaN    11693
# 493060                             Chihuahua      NaN    11693
# 493061                      Jindo Dog, Korea      NaN    11249
# 493062                  Old English Sheepdog      NaN    10024
#
#        LicenseIssuedDate LicenseExpiredDate  Extract Year  Unique Dog ID  \
# 0             09/12/2014         09/12/2017        2016.0            NaN
# 2             09/12/2014         09/12/2019        2016.0            NaN
# 12            09/13/2014         09/13/2019        2016.0            NaN
# 13            09/13/2014         09/13/2017        2016.0            NaN
# 18            09/13/2014         09/13/2019        2016.0            NaN
# ...                  ...                ...           ...            ...
# 493057        03/17/2021         03/17/2022           NaN            NaN
# 493059        03/17/2021         03/17/2022           NaN            NaN
# 493060        03/17/2021         03/17/2022           NaN            NaN
# 493061        03/17/2021         03/17/2022           NaN            NaN
# 493062        03/17/2021         03/17/2026           NaN            NaN
#
#          temp
# 0       12049
# 2       12027
# 12      13229
# 13      13234
# 18      12016
# ...       ...
# 493057  13224
# 493059  13713
# 493060  13713
# 493061  13269
# 493062  12040
#
# [104308 rows x 12 columns]
